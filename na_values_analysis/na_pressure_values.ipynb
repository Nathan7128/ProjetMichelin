# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# import other libraries when needed

# %%
# Load raw data
df = pd.read_parquet("..\dataDumper.parquet")
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\natha\AppData\Local\Temp\ipykernel_1884\2930624869.py:2: SyntaxWarning: invalid escape sequence '\d'
#   df = pd.read_parquet("..\dataDumper.parquet")

# %%
na_pressure_values = df[df.Pressure_Pa_1.isna()]
index_na_pressure_values = na_pressure_values.index

# %%
na_pressure_values.Time_utc.hist()
# Out:
# <Axes: >

# %%
range = 1000
i = 70
na_pressure_values_sample = df.loc[index_na_pressure_values[i] - range/2 : index_na_pressure_values[i] + range/2]
plt.plot(na_pressure_values_sample.Pressure_Pa_1)
